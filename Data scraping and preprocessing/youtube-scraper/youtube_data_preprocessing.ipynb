# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/VIT/Tamil Argumentation/
# Out:
# /content/gdrive/My Drive/VIT/Tamil Argumentation

# %%
# !ls
# Out:
#  EDA_Final.ipynb		   twitter_model_argument.pth
#  EDA_initial.ipynb		   twitter_model_argument_w3i.pth
#  html_tags_removal.ipynb	   twitter_model_quality.pth
#  Reliability.gdoc		   twitter_model_relevancy_upsample.pth
# 'Tamil argumentation paper.gdoc'   twitter_model_stance.pth
#  tamil_stopwords.txt		   twitter_model_writer.pth
#  Twitter_Argument_Dataset.xlsx	   XLM_ROBERTA_twitter-comments-3_inputs.ipynb
# 'Twitter Comment Dataset.xlsx'	   yt_comments_processed_1.gsheet
#  Twitter_Comment_Dataset.xlsx	   yt_comments_processed_1.xlsx
#  twitter-comment-quality.ipynb	   yt_comments_processed_2.gsheet
#  twitter-comments-3_inputs.ipynb   yt_comments_processed_2.xlsx

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("/content/gdrive/MyDrive/VIT/Tamil Argumentation/Dataset/Youtube/youtube_dataset_final.xlsx")

# %%
print(df["Comments"][4])
# Out:
# My health my rights <br><br>ஏண்டா குறுக்க மறுக்க வரீங்க

# %%
comments = []

for text in df['Comments']:
    text = str(text)
    text = text.replace("</a>", ' ')
    text = text.replace("</b>", ' ')
    text = text.replace("<a>", ' ')
    text = text.replace("<b>", ' ')
    text = text.replace("</i>", ' ')
    text = text.replace("<i>", ' ')
    text = text.replace("</br>", ' ')
    text = text.replace("<br>", ' ')
    text = text.replace("&nbsp", ' ')
    text = text.replace("\xa0", ' ')
    text = text.replace("♀", ' ')
    text = text.replace("\n", ' ')
    comments.append(text)

# %%
import re

emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # Emoticons
                           u"\U0001F300-\U0001F5FF"  # Symbols & Pictographs
                           u"\U0001F680-\U0001F6FF"  # Transport & Map Symbols
                           u"\U0001F700-\U0001F77F"  # Alchemical Symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U0001F004-\U0001F0CF"  # Playing Cards
                           u"\U0001F170-\U0001F251"  # Enclosed Ideographic Supplement
                           "]+", flags=re.UNICODE)

comments_processed = []

pattern = r'[\u200d\uFE0E\uFE0F]*'

for text in comments:

    text = re.sub(r'<a href=\"[a-zA-Z0-9:/.&?=#-_]*\">'," ",text)
    text = re.sub(pattern, '', text)
    text_without_emojis = emoji_pattern.sub(r'', text)
    comments_processed.append(text_without_emojis)

# %%
new_comments = pd.Series(comments_processed)
len(comments_processed)
# Out:
# 2137

# %%
df['Comments'] = new_comments

# %%
df.to_excel("/content/gdrive/MyDrive/VIT/Tamil Argumentation/Dataset/Youtube/youtube_dataset_final_processed.xlsx")
